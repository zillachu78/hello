# %%
# Step 1: Install spaCy correctly for the current kernel
import sys
# !{sys.executable} -m pip install spacy

# Step 2: Download the small English model
# !{sys.executable} -m spacy download en_core_web_sm

# Step 3: Import spaCy and load the model
import spacy
nlp = spacy.load("en_core_web_sm")

# Step 4: Define text and extract named entities
text = "Barack Obama went as a prime minister of USA in the year of 2015. PM MODI is the prime minister of INDIA."
doc = nlp(text)
named_entity = [ent.text for ent in doc.ents]

# Step 5: Print the extracted entities
print(named_entity)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#      - ------------------------------------- 0.5/12.8 MB 924.0 kB/s eta 0:00:14
#      - ------------------------------------- 0.5/12.8 MB 924.0 kB/s eta 0:00:14
#      - ------------------------------------- 0.5/12.8 MB 924.0 kB/s eta 0:00:14
# ...

# %%
#pip install spacy
import spacy
nlp = spacy.load("en_core_web_sm")

text = "Barack Obama went as a prime minister of USA in the year of 2015 . PM MODI is the prime minister of INDIA."
doc = nlp(text)
named_entity = []
for ent in doc.ents:
    named_entity.append(ent.text)
print(named_entity)
# Out:
# ['Barack Obama', 'USA', 'the year of 2015', 'PM MODI', 'INDIA']
